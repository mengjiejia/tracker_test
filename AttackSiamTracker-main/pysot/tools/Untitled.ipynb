# %%
import sys
# %run test.py --original --username mjia1
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 69.35it/s, uav5]
# (  1) Video: air conditioning box1 Time:   2.2s Speed: 201.7fps
# (  2) Video: air conditioning box2 Time:   9.1s Speed: 201.8fps
# (  3) Video: basketball player1 Time:   5.3s Speed: 199.2fps
# (  4) Video: basketball player1_1-n Time:   1.5s Speed: 202.4fps
# (  5) Video: basketball player1_2-n Time:   8.3s Speed: 188.3fps
# (  6) Video: basketball player2 Time:   8.4s Speed: 155.4fps
# (  7) Video: basketball player2-n Time:   7.9s Speed: 155.1fps
# (  8) Video: basketball player3 Time:   8.8s Speed: 150.6fps
# (  9) Video: basketball player3-n Time:   4.4s Speed: 167.5fps
# ( 10) Video: basketball player4-n Time:   2.7s Speed: 148.6fps
# ( 11) Video: bell tower   Time:  13.9s Speed: 148.2fps
# ( 12) Video: bike1        Time:   1.3s Speed: 132.9fps
# ( 13) Video: bike2        Time:   5.3s Speed: 158.3fps
# ( 14) Video: bike3        Time:   1.7s Speed: 139.1fps
# ...

# %%
# %run test.py --original --username mjia1 --video bike2 --img_save
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 72.92it/s, uav5]
# ( 13) Video: bike2        Time:   4.4s Speed: 189.6fps

# %%
# %run test.py --attack --username mjia1
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 70.22it/s, uav5]
# Attack to  air conditioning box1  from frame  1  to frame  437
# Testing  air conditioning box1  img  0
# Testing  air conditioning box1  img  200
# Testing  air conditioning box1  img  400
# Attack to  air conditioning box2  from frame  1  to frame  437
# Testing  air conditioning box2  img  0
# Testing  air conditioning box2  img  200
# Testing  air conditioning box2  img  400
# Testing  air conditioning box2  img  600
# Testing  air conditioning box2  img  800
# Testing  air conditioning box2  img  1000
# Testing  air conditioning box2  img  1200
# Testing  air conditioning box2  img  1400
# Testing  air conditioning box2  img  1600
# Testing  air conditioning box2  img  1800
# Attack to  basketball player1  from frame  1  to frame  437
# Testing  basketball player1  img  0
# Testing  basketball player1  img  200
# Testing  basketball player1  img  400
# ...

# %%
# %run test.py --attack --username mjia1 --video bike2 --img_save
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 70.88it/s, uav5]
# Attack to  bike2  from frame  1  to frame  437
# Testing  bike2  img  0
# Testing  bike2  img  200
# Testing  bike2  img  400
# Testing  bike2  img  600
# Testing  bike2  img  800

# %%
# %run eval.py --original --username mjia1
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 76.37it/s, uav5]
# eval success: 100%
# eval precision: 10
# Overall Performance
# ------------------------------------
# |Tracker name| Success | Precision |
# ------------------------------------
# |  original  |  0.617  |   0.813   |
# ------------------------------------
#
#
#
# Performance for each video
# ---------------------------------------------
# |    Tracker name     |      original       |
# ---------------------------------------------
# |     Video name      | success | precision |
# ---------------------------------------------
# |air conditioning box1|  0.743  |   0.959   |
# |air conditioning box2|  0.127  |   0.658   |
# | basketball player1  |  0.602  |   0.829   |
# |basketball player1_1-n|  0.613  |   0.953   |
# |basketball player1_2-n|  0.554  |   0.865   |
# | basketball player2  |  0.301  |   0.566   |
# |basketball player2-n |  0.570  |   0.772   |
# ...

# %%
# %run eval.py --attack --username mjia1
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 76.48it/s, uav5]
# eval success: 100%
# eval precision: 10
# Overall Performance
# ------------------------------------
# |Tracker name| Success | Precision |
# ------------------------------------
# |   attack   |  0.217  |   0.384   |
# ------------------------------------
#
#
#
# Performance for each video
# ---------------------------------------------
# |    Tracker name     |       attack        |
# ---------------------------------------------
# |     Video name      | success | precision |
# ---------------------------------------------
# |air conditioning box1|  0.438  |   0.886   |
# |air conditioning box2|  0.014  |   0.076   |
# | basketball player1  |  0.033  |   0.099   |
# |basketball player1_1-n|  0.436  |   0.891   |
# |basketball player1_2-n|  0.003  |   0.026   |
# | basketball player2  |  0.082  |   0.383   |
# |basketball player2-n |  0.605  |   0.899   |
# ...

# %%
# %run test.py --comparison --username mjia1 --video bike2 --img_save
# Out:
# loading V4RFlight112: 100%|█████████████████████████████████| 112/112 [00:01<00:00, 74.14it/s, uav5]

# %%
pip list
# Out:
# Package                   Version
# ------------------------- ----------
# anyio                     4.2.0
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# asttokens                 2.0.5
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.11.0
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    4.1.0
# Brotli                    1.0.9
# certifi                   2024.2.2
# cffi                      1.16.0
# chardet                   3.0.4
# charset-normalizer        2.0.4
# cmake                     3.29.3
# colorama                  0.4.4
# comm                      0.2.1
# cycler                    0.12.1
# Cython                    0.29.24
# debugpy                   1.6.7
# decorator                 5.1.1
# defusedxml                0.7.1
# dominate                  2.6.0
# exceptiongroup            1.2.0
# executing                 0.8.3
# ...
